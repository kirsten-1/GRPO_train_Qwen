# %%
import os
from modelscope import snapshot_download

# 1. 定义数据盘下的存放路径
# 建议先建立一个 models 文件夹方便管理
custom_path = '/root/autodl-tmp/models'

# 2. 如果文件夹不存在则创建
if not os.path.exists(custom_path):
    os.makedirs(custom_path)

# 3. 下载模型并指定 cache_dir
model_dir = snapshot_download(
    'Qwen/Qwen2.5-3B-Instruct', 
    cache_dir=custom_path
)

print(f"模型已成功下载至: {model_dir}")
# Out:
# Downloading Model from https://www.modelscope.cn to directory: /root/autodl-tmp/models/Qwen/Qwen2.5-3B-Instruct
# 2026-03-06 21:28:04,791 - modelscope - INFO - Got 12 files, start to download ...
# Processing 12 items:   0%|          | 0.00/12.0 [00:00<?, ?it/s]
# Downloading [configuration.json]:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading [generation_config.json]:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Downloading [model-00002-of-00002.safetensors]:   0%|          | 0.00/2.05G [00:00<?, ?B/s]
# Downloading [merges.txt]:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Downloading [model-00001-of-00002.safetensors]:   0%|          | 0.00/3.70G [00:00<?, ?B/s]
# Downloading [config.json]:   0%|          | 0.00/661 [00:00<?, ?B/s]
# Downloading [LICENSE]:   0%|          | 0.00/7.21k [00:00<?, ?B/s]
# Downloading [model.safetensors.index.json]:   0%|          | 0.00/34.7k [00:00<?, ?B/s]
# Downloading [README.md]:   0%|          | 0.00/4.81k [00:00<?, ?B/s]
# Downloading [tokenizer.json]:   0%|          | 0.00/6.71M [00:00<?, ?B/s]
# Downloading [tokenizer_config.json]:   0%|          | 0.00/7.13k [00:00<?, ?B/s]
# Downloading [vocab.json]:   0%|          | 0.00/2.65M [00:00<?, ?B/s]
# 2026-03-06 21:41:28,134 - modelscope - INFO - Download model 'Qwen/Qwen2.5-3B-Instruct' successfully.
# 2026-03-06 21:41:28,136 - modelscope - INFO - Creating symbolic link [/root/autodl-tmp/models/Qwen/Qwen2.5-3B-Instruct].
# 模型已成功下载至: /root/autodl-tmp/models/Qwen/Qwen2___5-3B-Instruct

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 from datasets import load_dataset
#       3 # 1. GSM8K（小学数学应用题）
# ----> 4 dataset_gsm8k = load_dataset(
#       5   "openai/gsm8k",
#       6   "main",
#       7   cache_dir="/root/autodl-tmp/datasets"
#       8 )
#      10 # 2. Ape210K（中文小学数学）
#      11 dataset_ape210k = load_dataset(
#      12   "m-a-p/Ape210K",
#      13   cache_dir="/root/autodl-tmp/datasets"
#      14 )
#
# File ~/miniconda3/lib/python3.12/site-packages/datasets/load.py:1485, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1480 verification_mode = VerificationMode(
#    1481     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1482 )
#    1484 # Create a dataset builder
# -> 1485 builder_instance = load_dataset_builder(
#    1486     path=path,
#    1487     name=name,
#    1488     data_dir=data_dir,
#    1489     data_files=data_files,
#    1490     cache_dir=cache_dir,
#    1491     features=features,
#    1492     download_config=download_config,
#    1493     download_mode=download_mode,
#    1494     revision=revision,
#    1495     token=token,
#    1496     storage_options=storage_options,
#    1497     **config_kwargs,
#    1498 )
#    1500 # Return iterable dataset in case of streaming
#    1501 if streaming:
#
# File ~/miniconda3/lib/python3.12/site-packages/datasets/load.py:1130, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1128 if features is not None:
#    1129     features = _fix_for_backward_compatible_features(features)
# -> 1130 dataset_module = dataset_module_factory(
#    1131     path,
#    1132     revision=revision,
#    1133     download_config=download_config,
#    1134     download_mode=download_mode,
#    1135     data_dir=data_dir,
#    1136     data_files=data_files,
#    1137     cache_dir=cache_dir,
#    1138 )
#    1139 # Get dataset builder class
#    1140 builder_kwargs = dataset_module.builder_kwargs
#
# File ~/miniconda3/lib/python3.12/site-packages/datasets/load.py:936, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#     934 try:
#     935     _raise_if_offline_mode_is_enabled()
# --> 936     dataset_readme_path = api.hf_hub_download(
#     937         repo_id=path,
#     938         filename=config.REPOCARD_FILENAME,
#     939         repo_type="dataset",
#     940         revision=revision,
#     941         proxies=download_config.proxies,
#     942     )
#     943     commit_hash = os.path.basename(os.path.dirname(dataset_readme_path))
#     944 except LocalEntryNotFoundError as e:
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/hf_api.py:5673, in HfApi.hf_hub_download(self, repo_id, filename, subfolder, repo_type, revision, cache_dir, local_dir, force_download, etag_timeout, token, local_files_only, tqdm_class, dry_run)
#    5669 if token is None:
#    5670     # Cannot do `token = token or self.token` as token can be `False`.
#    5671     token = self.token
# -> 5673 return hf_hub_download(
#    5674     repo_id=repo_id,
#    5675     filename=filename,
#    5676     subfolder=subfolder,
#    5677     repo_type=repo_type,
#    5678     revision=revision,
#    5679     endpoint=self.endpoint,
#    5680     library_name=self.library_name,
#    5681     library_version=self.library_version,
#    5682     cache_dir=cache_dir,
#    5683     local_dir=local_dir,
#    5684     user_agent=self.user_agent,
#    5685     force_download=force_download,
#    5686     etag_timeout=etag_timeout,
#    5687     token=token,
#    5688     headers=self.headers,
#    5689     local_files_only=local_files_only,
#    5690     tqdm_class=tqdm_class,
#    5691     dry_run=dry_run,
#    5692 )
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:982, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     961     return _hf_hub_download_to_local_dir(
#     962         # Destination
#     963         local_dir=local_dir,
#    (...)    979         dry_run=dry_run,
#     980     )
#     981 else:
# --> 982     return _hf_hub_download_to_cache_dir(
#     983         # Destination
#     984         cache_dir=cache_dir,
#     985         # File info
#     986         repo_id=repo_id,
#     987         filename=filename,
#     988         repo_type=repo_type,
#     989         revision=revision,
#     990         # HTTP info
#     991         endpoint=endpoint,
#     992         etag_timeout=etag_timeout,
#     993         headers=hf_headers,
#     994         token=token,
#     995         # Additional options
#     996         local_files_only=local_files_only,
#     997         force_download=force_download,
#     998         tqdm_class=tqdm_class,
#     999         dry_run=dry_run,
#    1000     )
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1115, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1109     if isinstance(head_call_error, _DEFAULT_RETRY_ON_EXCEPTIONS) or (
#    1110         isinstance(head_call_error, HfHubHTTPError)
#    1111         and head_call_error.response.status_code in _DEFAULT_RETRY_ON_STATUS_CODES
#    1112     ):
#    1113         logger.info("No local file found. Retrying..")
#    1114         (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = (
# -> 1115             _get_metadata_or_catch_error(
#    1116                 repo_id=repo_id,
#    1117                 filename=filename,
#    1118                 repo_type=repo_type,
#    1119                 revision=revision,
#    1120                 endpoint=endpoint,
#    1121                 etag_timeout=_ETAG_RETRY_TIMEOUT,
#    1122                 headers=headers,
#    1123                 token=token,
#    1124                 local_files_only=local_files_only,
#    1125                 storage_folder=storage_folder,
#    1126                 relative_filename=relative_filename,
#    1127                 retry_on_errors=True,
#    1128             )
#    1129         )
#    1131 # If still error, raise
#    1132 if head_call_error is not None:
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1649, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors)
#    1647 try:
#    1648     try:
# -> 1649         metadata = get_hf_file_metadata(
#    1650             url=url,
#    1651             timeout=etag_timeout,
#    1652             headers=headers,
#    1653             token=token,
#    1654             endpoint=endpoint,
#    1655             retry_on_errors=retry_on_errors,
#    1656         )
#    1657     except RemoteEntryNotFoundError as http_error:
#    1658         if storage_folder is not None and relative_filename is not None:
#    1659             # Cache the non-existence of the file
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1572, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1569 hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1571 # Retrieve metadata
# -> 1572 response = _httpx_follow_relative_redirects_with_backoff(
#    1573     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1574 )
#    1575 hf_raise_for_status(response)
#    1577 # Return
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:644, in _httpx_follow_relative_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     639 no_retry_kwargs: dict[str, Any] = (
#     640     {} if retry_on_errors else {"retry_on_exceptions": (), "retry_on_status_codes": ()}
#     641 )
#     643 while True:
# --> 644     response = http_backoff(
#     645         method=method,
#     646         url=url,
#     647         **httpx_kwargs,
#     648         follow_redirects=False,
#     649         **no_retry_kwargs,
#     650     )
#     651     hf_raise_for_status(response)
#     653     # Check if response is a relative redirect
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:518, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     453 def http_backoff(
#     454     method: HTTP_METHOD_T,
#     455     url: str,
#    (...)    462     **kwargs,
#     463 ) -> httpx.Response:
#     464     """Wrapper around httpx to retry calls on an endpoint, with exponential backoff.
#     465
#     466     Endpoint call is retried on exceptions (ex: connection timeout, proxy error,...)
#    (...)    516     > issue on [Github](https://github.com/huggingface/huggingface_hub).
#     517     """
# --> 518     return next(
#     519         _http_backoff_base(
#     520             method=method,
#     521             url=url,
#     522             max_retries=max_retries,
#     523             base_wait_time=base_wait_time,
#     524             max_wait_time=max_wait_time,
#     525             retry_on_exceptions=retry_on_exceptions,
#     526             retry_on_status_codes=retry_on_status_codes,
#     527             stream=False,
#     528             **kwargs,
#     529         )
#     530     )
#
# File ~/miniconda3/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:426, in _http_backoff_base(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, stream, **kwargs)
#     424             return
#     425 else:
# --> 426     response = client.request(method=method, url=url, **kwargs)
#     427     if not _should_retry(response):
#     428         yield response
#
# File ~/miniconda3/lib/python3.12/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/miniconda3/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniconda3/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniconda3/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/miniconda3/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      99 except BaseException as exc:
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      76 with self._request_lock:
#      77     if self._connection is None:
# ---> 78         stream = self._connect(request)
#      80         ssl_object = stream.get_extra_info("ssl_object")
#      81         http2_negotiated = (
#      82             ssl_object is not None
#      83             and ssl_object.selected_alpn_protocol() == "h2"
#      84         )
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     116     kwargs = {
#     117         "host": self._origin.host.decode("ascii"),
#     118         "port": self._origin.port,
#    (...)    121         "socket_options": self._socket_options,
#     122     }
#     123     with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124         stream = self._network_backend.connect_tcp(**kwargs)
#     125         trace.return_value = stream
#     126 else:
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_backends/sync.py:208, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
#     207 with map_exceptions(exc_map):
# --> 208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#     213     for option in socket_options:
#     214         sock.setsockopt(*option)  # pragma: no cover
#
# File ~/miniconda3/lib/python3.12/socket.py:837, in create_connection(address, timeout, source_address, all_errors)
#     835 if source_address:
#     836     sock.bind(source_address)
# --> 837 sock.connect(sa)
#     838 # Break explicitly a reference cycle
#     839 exceptions.clear()
#
# KeyboardInterrupt:
